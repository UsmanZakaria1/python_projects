# %% [markdown]
# Read the file "Scroe.csv".
#
# Fill the Null or NA values with average of respective student.

# %%
import pandas as pd
score=pd.read_csv("Score.csv")
null = score.isnull().any(axis=1)
null_rows = score[null]
print('Null Rows')
display(null_rows)
mean=score[score.isnull().any(axis=1)].iloc[:,[3,4,5,6,7,8]].mean(axis=1)
score['L05'].fillna(mean,inplace=True)
print('After Removing The Null Values')
score.head(22)
# Out:
# Null Rows
#     S.No                        Subject Section  L01   L02   L03  L04  L05  \
# 20    21  Introduction to Computing Lab      DM  9.0  10.0  10.0   10  NaN
#
#     L06
# 20  0.0
# After Removing The Null Values
#     S.No                        Subject Section   L01   L02   L03  L04   L05  \
# 0      1  Introduction to Computing Lab      DM   6.0   6.0  10.0    5  10.0
# 1      2  Introduction to Computing Lab      DM  10.0  10.0  10.0    9  10.0
# 2      3  Introduction to Computing Lab      DM   7.0   7.0  10.0    9  10.0
# 3      4  Introduction to Computing Lab      DM   9.0   7.0  10.0    7  10.0
# 4      5  Introduction to Computing Lab      DM   3.0  10.0  10.0   10   0.0
# 5      6  Introduction to Computing Lab      DM   6.0   7.0  10.0    6  10.0
# 6      7  Introduction to Computing Lab      DM   9.0  10.0  10.0   10  10.0
# 7      8  Introduction to Computing Lab      DM   7.0  10.0  10.0    9  10.0
# 8      9  Introduction to Computing Lab      DM   6.0  10.0  10.0   10  10.0
# 9     10  Introduction to Computing Lab      DM   4.0   7.0  10.0    7  10.0
# 10    11  Introduction to Computing Lab      DM   5.0   7.0  10.0    6  10.0
# 11    12  Introduction to Computing Lab      DM   4.0   8.0  10.0    5  10.0
# 12    13  Introduction to Computing Lab      DM   8.0   7.0  10.0   10  10.0
# 13    14  Introduction to Computing Lab      DM  10.0  10.0  10.0   10  10.0
# 14    15  Introduction to Computing Lab      DM   4.0   8.0  10.0    9  10.0
# 15    16  Introduction to Computing Lab      DM   8.0   9.0  10.0    9  10.0
# 16    17  Introduction to Computing Lab      DM   3.0   7.0  10.0    3  10.0
# 17    18  Introduction to Computing Lab      DM   6.0  10.0  10.0   10  10.0
# 18    19  Introduction to Computing Lab      DM  10.0  10.0  10.0   10  10.0
# 19    20  Introduction to Computing Lab      DM   3.0   7.0  10.0    7  10.0
# 20    21  Introduction to Computing Lab      DM   9.0  10.0  10.0   10   7.8
# 21    22  Introduction to Computing Lab      DM   0.0   4.0  10.0    6  10.0
#
#     L06
# 0   6.5
# 1   7.0
# 2   0.0
# 3   6.0
# 4   0.0
# 5   7.0
# 6   7.0
# 7   7.0
# 8   0.0
# 9   6.0
# 10  6.0
# 11  6.0
# 12  0.0
# 13  0.0
# 14  6.0
# 15  7.0
# 16  6.0
# 17  0.0
# 18  7.0
# 19  6.0
# 20  0.0
# 21  6.0

# %% [markdown]
# Calculate Avgerage of Each student and store in the column named as "Avg"

# %%
score['Avg'] = score.iloc[:, [3, 4, 5, 6,7, 8]].mean(axis=1)

# Display the updated DataFrame
display(score.head())
# Out:
#    S.No                        Subject Section   L01   L02   L03  L04   L05  \
# 0     1  Introduction to Computing Lab      DM   6.0   6.0  10.0    5  10.0
# 1     2  Introduction to Computing Lab      DM  10.0  10.0  10.0    9  10.0
# 2     3  Introduction to Computing Lab      DM   7.0   7.0  10.0    9  10.0
# 3     4  Introduction to Computing Lab      DM   9.0   7.0  10.0    7  10.0
# 4     5  Introduction to Computing Lab      DM   3.0  10.0  10.0   10   0.0
#
#    L06       Avg
# 0  6.5  7.250000
# 1  7.0  9.333333
# 2  0.0  7.166667
# 3  6.0  8.166667
# 4  0.0  5.500000

# %% [markdown]
# On the basis of Average, calculate the progress of student.
#
#
#
# ```
# if average > 5 then set progress to Good,
# else if average == 5 then progress is average
# else set progress to below average.
# ```

# %%
def determine_progress(average):
    if average > 5:
        return 'Good'
    elif average == 5:
        return 'Average'
    else:
        return 'Below Average'

# Apply the function to create the "Progress" column
score['Progress'] = score['Avg'].apply(determine_progress)
display(score)
# Out:
#      S.No                        Subject Section   L01   L02   L03  L04   L05  \
# 0       1  Introduction to Computing Lab      DM   6.0   6.0  10.0    5  10.0
# 1       2  Introduction to Computing Lab      DM  10.0  10.0  10.0    9  10.0
# 2       3  Introduction to Computing Lab      DM   7.0   7.0  10.0    9  10.0
# 3       4  Introduction to Computing Lab      DM   9.0   7.0  10.0    7  10.0
# 4       5  Introduction to Computing Lab      DM   3.0  10.0  10.0   10   0.0
# ..    ...                            ...     ...   ...   ...   ...  ...   ...
# 165   166  Introduction to Computing Lab      EM  10.0  10.0  10.0   10  10.0
# 166   167  Introduction to Computing Lab      EM   7.0   7.0  10.0   10  10.0
# 167   168  Introduction to Computing Lab      EM   8.0   7.0  10.0   10   8.0
# 168   169  Introduction to Computing Lab      EM  10.0  10.0   9.0   10   0.0
# 169   170  Introduction to Computing Lab      EM   5.0   5.0   7.0    0  10.0
#
#       L06        Avg Progress
# 0     6.5   7.250000     Good
# 1     7.0   9.333333     Good
# 2     0.0   7.166667     Good
# 3     6.0   8.166667     Good
# 4     0.0   5.500000     Good
# ..    ...        ...      ...
# 165  10.0  10.000000     Good
# 166   7.0   8.500000     Good
# 167  10.0   8.833333     Good
# 168   7.0   7.666667     Good
# 169   7.0   5.666667     Good
#
# [170 rows x 11 columns]

# %% [markdown]
# Transform Categorical values into Numerical values.

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()


score['Progress Numeric'] = label_encoder.fit_transform(score['Progress'])
score['Subject Numeric'] = label_encoder.fit_transform(score['Subject'])
score['Section Numeric'] = label_encoder.fit_transform(score['Subject'])
display(score)
# Out:
#      S.No                        Subject Section   L01   L02   L03  L04   L05  \
# 0       1  Introduction to Computing Lab      DM   6.0   6.0  10.0    5  10.0
# 1       2  Introduction to Computing Lab      DM  10.0  10.0  10.0    9  10.0
# 2       3  Introduction to Computing Lab      DM   7.0   7.0  10.0    9  10.0
# 3       4  Introduction to Computing Lab      DM   9.0   7.0  10.0    7  10.0
# 4       5  Introduction to Computing Lab      DM   3.0  10.0  10.0   10   0.0
# ..    ...                            ...     ...   ...   ...   ...  ...   ...
# 165   166  Introduction to Computing Lab      EM  10.0  10.0  10.0   10  10.0
# 166   167  Introduction to Computing Lab      EM   7.0   7.0  10.0   10  10.0
# 167   168  Introduction to Computing Lab      EM   8.0   7.0  10.0   10   8.0
# 168   169  Introduction to Computing Lab      EM  10.0  10.0   9.0   10   0.0
# 169   170  Introduction to Computing Lab      EM   5.0   5.0   7.0    0  10.0
#
#       L06        Avg Progress  Progress Numeric  Subject Numeric  \
# 0     6.5   7.250000     Good                 2                1
# 1     7.0   9.333333     Good                 2                1
# 2     0.0   7.166667     Good                 2                1
# 3     6.0   8.166667     Good                 2                1
# 4     0.0   5.500000     Good                 2                1
# ..    ...        ...      ...               ...              ...
# 165  10.0  10.000000     Good                 2                1
# 166   7.0   8.500000     Good                 2                1
# 167  10.0   8.833333     Good                 2                1
# 168   7.0   7.666667     Good                 2                1
# 169   7.0   5.666667     Good                 2                1
#
#      Section Numeric
# 0                  1
# 1                  1
# 2                  1
# 3                  1
# 4                  1
# ..               ...
# 165                1
# 166                1
# 167                1
# 168                1
# 169                1
#
# [170 rows x 14 columns]

# %% [markdown]
# Set the s to all the columns except s.no and progress.
#
# Set the label variable to progress.
#
# Split the dataset into test and train.
#   1. 1st time train set is set to 70 and test 30
#   2. For second time split into 0.20
#   3. For third time split into 1:3

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
features = score.drop(columns=['S.No', 'Progress','Subject','Section'])


label = score['Progress Numeric']
# 1st time train set is set to 70 and test 30

X_train_1, X_test_1, y_train_1, y_test_1 = train_test_split(features, label, test_size=0.3, random_state=42)

# For second time split into 0.20
X_train_2, X_test_2, y_train_2, y_test_2 = train_test_split(features, label, test_size=0.2, random_state=42)

# For third time split into 1:3
X_train_3, X_test_3, y_train_3, y_test_3 = train_test_split(features, label, test_size=0.25, random_state=42)

# %% [markdown]
# Apply all the Machine algorithm we had covered in our course to predict the progress of student.

# %%
# Import necessary libraries for machine learning algorithms
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, mean_squared_error
import warnings
warnings.filterwarnings("ignore")

# Initialize models

logistic_reg_model = LogisticRegression()
random_forest_model = RandomForestClassifier(random_state=42)
decision_tree_model = DecisionTreeClassifier(random_state=42)


# Logistic Regression model(1)
logistic_reg_model.fit(X_train_1, y_train_1)
logistic_reg_predictions_1 = logistic_reg_model.predict(X_test_1)
logistic_reg_accuracy_1 = accuracy_score(y_test_1, logistic_reg_predictions_1)

#  Logistic Regression model(2)
logistic_reg_model.fit(X_train_2, y_train_2)
logistic_reg_predictions_2 = logistic_reg_model.predict(X_test_2)
logistic_reg_accuracy_2 = accuracy_score(y_test_2, logistic_reg_predictions_2)

#  Logistic Regression model(3)
logistic_reg_model.fit(X_train_3, y_train_3)
logistic_reg_predictions_3 = logistic_reg_model.predict(X_test_3)
logistic_reg_accuracy_3 = accuracy_score(y_test_3, logistic_reg_predictions_3)


#  Random Forest model(1)
random_forest_model.fit(X_train_1, y_train_1)
random_forest_predictions_1 = random_forest_model.predict(X_test_1)
random_forest_accuracy_1 = accuracy_score(y_test_1, random_forest_predictions_1)

#  Random Forest model(2)
random_forest_model.fit(X_train_2, y_train_2)
random_forest_predictions_2 = random_forest_model.predict(X_test_2)
random_forest_accuracy_2 = accuracy_score(y_test_2, random_forest_predictions_2)

#  Random Forest model(3)
random_forest_model.fit(X_train_3, y_train_3)
random_forest_predictions_3 = random_forest_model.predict(X_test_3)
random_forest_accuracy_3 = accuracy_score(y_test_3, random_forest_predictions_3)

#  Decision Tree model(1)
decision_tree_model.fit(X_train_1, y_train_1)
decision_tree_predictions_1 = decision_tree_model.predict(X_test_1)
decision_tree_accuracy_1 = accuracy_score(y_test_1, decision_tree_predictions_1)

#  Decision Tree model(2)
decision_tree_model.fit(X_train_2, y_train_2)
decision_tree_predictions_2 = decision_tree_model.predict(X_test_2)
decision_tree_accuracy_2 = accuracy_score(y_test_2, decision_tree_predictions_2)

#  Decision Tree model(3)
decision_tree_model.fit(X_train_3, y_train_3)
decision_tree_predictions_3 = decision_tree_model.predict(X_test_3)
decision_tree_accuracy_3 = accuracy_score(y_test_3, decision_tree_predictions_3)

#  evaluation results

print(f"Logistic Regression Accuracy (Split 1): {logistic_reg_accuracy_1}")
print(f"Logistic Regression Accuracy (Split 2): {logistic_reg_accuracy_2}")
print(f"Logistic Regression Accuracy (Split 3): {logistic_reg_accuracy_3}")
print(f"Random Forest Accuracy (Split 1): {random_forest_accuracy_1}")
print(f"Random Forest Accuracy (Split 2): {random_forest_accuracy_2}")
print(f"Random Forest Accuracy (Split 3): {random_forest_accuracy_3}")
print(f"Decision Tree Accuracy (Split 1): {decision_tree_accuracy_1}")
print(f"Decision Tree Accuracy (Split 2): {decision_tree_accuracy_2}")
print(f"Decision Tree Accuracy (Split 3): {decision_tree_accuracy_3}")
# Out:
# Logistic Regression Accuracy (Split 1): 0.9803921568627451
# Logistic Regression Accuracy (Split 2): 0.9705882352941176
# Logistic Regression Accuracy (Split 3): 0.9767441860465116
# Random Forest Accuracy (Split 1): 0.9803921568627451
# Random Forest Accuracy (Split 2): 0.9705882352941176
# Random Forest Accuracy (Split 3): 0.9767441860465116
# Decision Tree Accuracy (Split 1): 1.0
# Decision Tree Accuracy (Split 2): 1.0
# Decision Tree Accuracy (Split 3): 1.0

# %% [markdown]
# Self Learn:
#
# Learn a new Machine Learning Algorithm Which is not covered in our course and implement it on our score dataset for the prediction of Progress of student.

# %%
# Self Learn model is SVM
#SVM: Support vector machines (SVMs) are a set of supervised learning methods
#used for classification, regression and outliers detection
# Import necessary library for Support Vector Machine

from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

# Initialize Support Vector Machine model
svm_model = SVC(random_state=42)

#  Support Vector Machine model (Split 1)
svm_model.fit(X_train_1, y_train_1)
svm_predictions_1 = svm_model.predict(X_test_1)
svm_accuracy_1 = accuracy_score(y_test_1, svm_predictions_1)

#  Support Vector Machine model (Split 2)
svm_model.fit(X_train_2, y_train_2)
svm_predictions_2 = svm_model.predict(X_test_2)
svm_accuracy_2 = accuracy_score(y_test_2, svm_predictions_2)

#  Support Vector Machine model (Split 3)
svm_model.fit(X_train_3, y_train_3)
svm_predictions_3 = svm_model.predict(X_test_3)
svm_accuracy_3 = accuracy_score(y_test_3, svm_predictions_3)

# evaluation results
print(f"Support Vector Machine Accuracy (Split 1): {svm_accuracy_1}")
print(f"Support Vector Machine Accuracy (Split 2): {svm_accuracy_2}")
print(f"Support Vector Machine Accuracy (Split 3): {svm_accuracy_3}")
# Out:
# Support Vector Machine Accuracy (Split 1): 0.9803921568627451
# Support Vector Machine Accuracy (Split 2): 0.9705882352941176
# Support Vector Machine Accuracy (Split 3): 0.9767441860465116

# %% [markdown]
# #Do's
#
# For each model , use each spliting and get three different results.
#
# Compare the all the model on each spliting.
#
# Result : generate result on the basis of our your thinking.
#
# Visualize your dataset on the each model using matplotlib.

# %% [markdown]
# ### *I have applied four AI models, the  Random Forest demonstrates the highest accuracy across the three different splits.*

# %%
import matplotlib.pyplot as plt

# Create lists for model names, accuracies, and splits

models = ['Logistic Regression', 'Random Forest', 'Decision Tree', 'Support Vector Machine']
accuracies_1 = [logistic_reg_accuracy_1, random_forest_accuracy_1, decision_tree_accuracy_1, svm_accuracy_1]
accuracies_2 = [logistic_reg_accuracy_2, random_forest_accuracy_2, decision_tree_accuracy_2, svm_accuracy_2]
accuracies_3 = [logistic_reg_accuracy_3, random_forest_accuracy_3, decision_tree_accuracy_3, svm_accuracy_3]

splits = ['Split 1', 'Split 2', 'Split 3']

# Plotting the results
for i in range(len(models)):
    plt.figure(figsize=(10, 5))

    plt.bar(splits, [accuracies_1[i], accuracies_2[i], accuracies_3[i]], color=['lightblue', 'lightgreen', 'salmon'])
    plt.title(f'Accuracy Comparison for {models[i]}')
    plt.ylim(0, 1)
    plt.ylabel('Accuracy')
    plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

models = ['Logistic Regression', 'Random Forest', 'Decision Tree', 'Support Vector Machine']
accuracies_1 = [logistic_reg_accuracy_1, random_forest_accuracy_1, decision_tree_accuracy_1, svm_accuracy_1]
accuracies_2 = [logistic_reg_accuracy_2, random_forest_accuracy_2, decision_tree_accuracy_2, svm_accuracy_2]
accuracies_3 = [logistic_reg_accuracy_3, random_forest_accuracy_3, decision_tree_accuracy_3, svm_accuracy_3]

splits = ['Split 1', 'Split 2', 'Split 3']

# Plotting the results with different colors
bar_width = 0.2
bar_positions = np.arange(len(splits))

colors = ['lightblue', 'lightgreen', 'lightcoral']  # Updated attractive colors

for i in range(len(models)):
    plt.bar(bar_positions + i * bar_width, [accuracies_1[i], accuracies_2[i], accuracies_3[i]],
            width=bar_width, label=models[i], color=colors[i % len(colors)])

plt.xlabel('Splits')
plt.ylabel('Accuracy')
plt.title('Accuracy Comparison for Different Models Across Splits')
plt.xticks(bar_positions + bar_width * (len(models) - 1) / 2, splits)
plt.legend()
plt.show()
